# %%
import os

# 获取当前工作目录
current_dir = os.getcwd()
print("当前工作目录：", current_dir)
 
# 切换到上一层目录
parent_dir = os.path.dirname(current_dir)
os.chdir(parent_dir)
print("切换后的目录：", parent_dir)
# Out:
# 当前工作目录： c:\Users\zhaoxs3\Downloads\NEMESIS\unit_test
# 切换后的目录： c:\Users\zhaoxs3\Downloads\NEMESIS

# %%
from nemesis.utils import *
from nemesis.products.rates import *
# Out:
# ####################################################################
# #  NEMESIS ALPHA Version 0.1.0 - This build: 24 Jan 2025 at 10:42 #
# ####################################################################

# %% [markdown]
# # Build SOFR curve

# %%
value_dt = Date(17,12,2024)
spot_days = 2
cal_type = CalendarTypes.UNITED_STATES
cal = Calendar(cal_type)
settle_dt = cal.add_business_days(value_dt, spot_days)

notional = 1000000

fixed_type = SwapTypes.PAY
fixed_freq = FrequencyTypes.ANNUAL
fixed_dc_type = DayCountTypes.ACT_360

spread = 0
float_freq = FrequencyTypes.ANNUAL
float_dc_type = DayCountTypes.ACT_360

bd_type = BusDayAdjustTypes.FOLLOWING
dg_type = DateGenRuleTypes.BACKWARD

# %%
swap_mkt_data = pd.read_excel("./unit_test/data/effr_curve_data_20241217.xlsx", sheet_name='swap')

# %%
maturity_dates = [settle_dt.add_business_tenor(tenor, cal_type=CalendarTypes.UNITED_STATES) for tenor in swap_mkt_data["Tenor"]]

swaps = [
    OIS(
        effective_dt = settle_dt,
        term_dt_or_tenor = tenor,
        fixed_leg_type = fixed_type,
        fixed_cpn = rate,
        fixed_freq_type = fixed_freq,
        fixed_dc_type = fixed_dc_type,
        notional = notional,
        payment_lag = 2,
        float_spread = spread,
        float_freq_type = float_freq,
        float_dc_type = float_dc_type,
        cal_type = cal_type,
        bd_type = bd_type,
        dg_type = dg_type
    )
    for tenor, rate in zip(swap_mkt_data["Tenor"], swap_mkt_data["Rate"]) 
]

# %%
payment_dates = maturity_dates.copy()
idx = np.where(np.array(payment_dates) == settle_dt.add_business_tenor("18M", cal_type=CalendarTypes.UNITED_STATES))[0][0]
payment_dates[idx:] = [cal.add_business_days(pivot, 2) for pivot in payment_dates[idx:]]

# %%
effr_curve = OISCurve(value_dt, [], [], swaps, interp_type=InterpTypes.LINEAR_ZERO_RATES)

# %%
effr_curve
# Out:
# OBJECT TYPE: OISCurve
# VALUATION DATE: 17-DEC-2024
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 26-DEC-2024
# MATURITY DATE: 26-DEC-2024
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.043420000076293944
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 26-DEC-2024
# MATURITY DATE: 26-DEC-2024
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 02-JAN-2025
# MATURITY DATE: 02-JAN-2025
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.0434154987335205
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 02-JAN-2025
# MATURITY DATE: 02-JAN-2025
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 09-JAN-2025
# MATURITY DATE: 09-JAN-2025
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.04343000411987305
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 09-JAN-2025
# MATURITY DATE: 09-JAN-2025
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-JAN-2025
# MATURITY DATE: 21-JAN-2025
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.043486995697021504
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-JAN-2025
# MATURITY DATE: 21-JAN-2025
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-FEB-2025
# MATURITY DATE: 19-FEB-2025
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.04342949867248535
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-FEB-2025
# MATURITY DATE: 19-FEB-2025
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-MAR-2025
# MATURITY DATE: 19-MAR-2025
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.043406505584716794
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-MAR-2025
# MATURITY DATE: 19-MAR-2025
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-APR-2025
# MATURITY DATE: 21-APR-2025
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.04309499740600585
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-APR-2025
# MATURITY DATE: 21-APR-2025
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-MAY-2025
# MATURITY DATE: 19-MAY-2025
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.0429119968414307
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-MAY-2025
# MATURITY DATE: 19-MAY-2025
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-JUN-2025
# MATURITY DATE: 19-JUN-2025
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.0427340030670166
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-JUN-2025
# MATURITY DATE: 19-JUN-2025
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-SEP-2025
# MATURITY DATE: 19-SEP-2025
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.0421600008010864
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-SEP-2025
# MATURITY DATE: 19-SEP-2025
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2025
# MATURITY DATE: 19-DEC-2025
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.041753001213073695
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2025
# MATURITY DATE: 19-DEC-2025
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-JUN-2026
# MATURITY DATE: 19-JUN-2026
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.0407307004928589
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-JUN-2026
# MATURITY DATE: 19-JUN-2026
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2026
# MATURITY DATE: 21-DEC-2026
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.040360002517700194
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2026
# MATURITY DATE: 21-DEC-2026
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2027
# MATURITY DATE: 20-DEC-2027
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.039709005355835
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2027
# MATURITY DATE: 20-DEC-2027
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2028
# MATURITY DATE: 19-DEC-2028
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.03923500061035155
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2028
# MATURITY DATE: 19-DEC-2028
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2029
# MATURITY DATE: 19-DEC-2029
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.038942999839782694
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2029
# MATURITY DATE: 19-DEC-2029
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2030
# MATURITY DATE: 19-DEC-2030
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.038780002593994146
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2030
# MATURITY DATE: 19-DEC-2030
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2031
# MATURITY DATE: 19-DEC-2031
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.0386829996109009
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2031
# MATURITY DATE: 19-DEC-2031
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2032
# MATURITY DATE: 20-DEC-2032
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.0386374998092651
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2032
# MATURITY DATE: 20-DEC-2032
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2033
# MATURITY DATE: 19-DEC-2033
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.03862800121307375
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2033
# MATURITY DATE: 19-DEC-2033
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2034
# MATURITY DATE: 19-DEC-2034
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.03865399837493895
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2034
# MATURITY DATE: 19-DEC-2034
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2036
# MATURITY DATE: 19-DEC-2036
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.038791999816894546
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2036
# MATURITY DATE: 19-DEC-2036
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2039
# MATURITY DATE: 19-DEC-2039
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.0389514970779419
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2039
# MATURITY DATE: 19-DEC-2039
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# SWAP:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2044
# MATURITY DATE: 19-DEC-2044
# NOTIONAL: 1000000
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.03876699924468995
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-DEC-2024
# TERMINATION DATE: 19-DEC-2044
# MATURITY DATE: 19-DEC-2044
# NOTIONAL: 1000000
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
# INTERP TYPE: InterpTypes.LINEAR_ZERO_RATES
# GRID TIMES: GRID DFS
#   0.000000: 1.0000000000
#   0.035616: 0.9984339446
#   0.054795: 0.9975942792
#   0.073973: 0.9967497637
#   0.101370: 0.9955494802
#   0.180822: 0.9920998824
#   0.257534: 0.9887908373
#   0.347945: 0.9850262720
#   0.424658: 0.9818574331
#   0.515068: 0.9781731723
#   0.767123: 0.9682545118
#   1.016438: 0.9587451426
#   1.515068: 0.9403662628
#   2.016438: 0.9223588637
#   3.013699: 0.8879552229
#   4.013699: 0.8552669417
#   5.013699: 0.8238127224
#   6.019178: 0.7931902964
#   7.019178: 0.7637496855
#   8.019178: 0.7352239279
#   9.016438: 0.7076488880
#  10.016438: 0.6807707910
#  12.024658: 0.6289408825
#  15.019178: 0.5586520287
#  20.024658: 0.4624941242

# %%
effr_curve.print_table(payment_dates)
# Out:
#           Date       ZR        DF
# 0   2024-12-26  4.40045  0.998916
# 1   2025-01-02  4.39843  0.998074
# 2   2025-01-09  4.39799  0.997233
# 3   2025-01-21  4.40034  0.995789
# 4   2025-02-19  4.38731  0.992337
# 5   2025-03-19  4.37773  0.989026
# 6   2025-04-21  4.33851  0.985252
# 7   2025-05-19  4.31326  0.982082
# 8   2025-06-19  4.28785  0.978616
# 9   2025-09-19  4.20881  0.968676
# 10  2025-12-19  4.14752  0.959155
# 11  2026-06-23  4.05829  0.940366
# 12  2026-12-23  4.00810  0.922359
# 13  2027-12-22  3.94313  0.887955
# 14  2028-12-21  3.89520  0.855267
# 15  2029-12-21  3.86565  0.823813
# 16  2030-12-23  3.84923  0.793190
# 17  2031-12-23  3.83970  0.763750
# 18  2032-12-22  3.83556  0.735224
# 19  2033-12-21  3.83530  0.707649
# 20  2034-12-21  3.83899  0.680771
# 21  2036-12-23  3.85639  0.628941
# 22  2039-12-21  3.87657  0.558652
# 23  2044-12-21  3.85086  0.462494

# %%
effr_curve.print_figure(payment_dates)

# %% [markdown]
# # IRS Valuation

# %%
swap = OIS(
    effective_dt=Date(19, 12, 2024),
    term_dt_or_tenor=Date(19, 12, 2025),
    fixed_leg_type=SwapTypes.RECEIVE,
    fixed_cpn=0.042,
    fixed_freq_type=FrequencyTypes.ANNUAL,
    fixed_dc_type=DayCountTypes.ACT_360,
    notional=1e10,
    payment_lag=2,
    float_spread=0,
    float_freq_type=FrequencyTypes.ANNUAL,
    float_dc_type=DayCountTypes.ACT_360,
    cal_type=CalendarTypes.UNITED_STATES,
    bd_type=BusDayAdjustTypes.MODIFIED_FOLLOWING,
    dg_type=DateGenRuleTypes.BACKWARD
)

# %%
swap
# Out:
# OBJECT TYPE: OIS
# OBJECT TYPE: SwapFixedLeg
# START DATE: 19-JUL-2024
# TERMINATION DATE: 18-JUL-2027
# MATURITY DATE: 19-JUL-2027
# NOTIONAL: 32061781.09
# PRINCIPAL: 0.0
# LEG TYPE: SwapTypes.PAY
# COUPON: 0.05558
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.MODIFIED_FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD
#
# OBJECT TYPE: SwapFloatLeg
# START DATE: 19-JUL-2024
# TERMINATION DATE: 18-JUL-2027
# MATURITY DATE: 19-JUL-2027
# NOTIONAL: 32061781.09
# SWAP TYPE: SwapTypes.RECEIVE
# SPREAD (BPS): 0
# FREQUENCY: FrequencyTypes.ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.UNITED_STATES
# BUS DAY ADJUST: BusDayAdjustTypes.MODIFIED_FOLLOWING
# DATE GEN TYPE: DateGenRuleTypes.BACKWARD

# %%
swap.value(value_dt=value_dt, ois_curve=effr_curve)
# Out:
# np.float64(2400978.9952175617)
